# %% [markdown]
# <a href="https://colab.research.google.com/github/Sezeri/CryptoClustering-/blob/main/Crypto_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries and dependencies
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install hvplot
# Out:
# Requirement already satisfied: hvplot in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from hvplot) (3.4.1)
# Requirement already satisfied: colorcet>=2 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from hvplot) (3.1.0)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from hvplot) (1.19.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from hvplot) (1.26.4)
# Requirement already satisfied: packaging in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from hvplot) (23.2)
# Requirement already satisfied: pandas in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from hvplot) (2.2.2)
# Requirement already satisfied: panel>=0.11.0 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from hvplot) (1.4.4)
# Requirement already satisfied: param<3.0,>=1.12.0 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from hvplot) (2.1.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (1.2.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (10.3.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (2022.9.0)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from holoviews>=1.11.0->hvplot) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from pandas->hvplot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from pandas->hvplot) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from pandas->hvplot) (2023.3)
# Requirement already satisfied: markdown in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (0.3.0)
# Requirement already satisfied: requests in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.32.2)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.66.4)
# Requirement already satisfied: bleach in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.1.3)
# Requirement already satisfied: six>=1.5 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->hvplot) (1.16.0)
# Requirement already satisfied: colorama in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=0.11.0->hvplot) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from linkify-it-py->panel>=0.11.0->hvplot) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from markdown-it-py->panel>=0.11.0->hvplot) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\phessou\appdata\local\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2024.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import holoviews as hv
#import hvplot.pandas
import matplotlib.pyplot as plt
# %matplotlib inline


#hv.extension('matplotlib')

# %%
#matplotlib.use('TkAgg')

# %%
# Load the data into a Pandas DataFrame and make the index the "coin_id" column.
market_data_df = pd.read_csv("../Resources/crypto_market_data.csv", index_col="coin_id")

# Display sample data
market_data_df.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                              6.57509                      7.67258
# ethereum                             4.80849                      0.13169
# tether                               0.00640                     -0.04237
# ripple                               2.24984                      0.23455
# bitcoin-cash                        14.75334                     15.74903
# binancecoin                          6.80688                      0.05865
# chainlink                            9.30098                    -11.21747
# cardano                              5.55476                     10.10553
# litecoin                             7.28931                      1.21662
# bitcoin-cash-sv                     -1.86656                      2.88926
#
#                  price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# bitcoin                             -3.25185                      83.51840
# ethereum                           -12.88890                     186.77418
# tether                               0.28037                      -0.00542
# ripple                             -17.55245                      39.53888
# bitcoin-cash                       -13.71793                      21.66042
# binancecoin                         36.33486                     155.61937
# chainlink                          -43.69522                     403.22917
# cardano                            -22.84776                     264.51418
# litecoin                           -17.23960                      27.49919
# bitcoin-cash-sv                    -24.87434                       7.42562
#
#                  price_change_percentage_1y
# coin_id
# bitcoin                            37.51761
# ethereum                          101.96023
# tether                              0.01954
# ripple                            -16.60193
# bitcoin-cash                       14.49384
# binancecoin                        69.69195
# chainlink                         325.13186
# cardano                           156.09756
# litecoin                          -12.66408
# bitcoin-cash-sv                    93.73082

# %%
# Generate summary statistics
market_data_df.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# 50%                       0.109740                    -0.042370
# 75%                       5.510740                     4.578130
# max                      24.239190                   140.795700
#
#        price_change_percentage_60d  price_change_percentage_200d  \
# count                    41.000000                     41.000000
# mean                     -0.094119                    236.537432
# std                      47.365803                    435.225304
# min                     -44.822480                     -0.392100
# 25%                     -25.907990                     21.660420
# 50%                      -7.544550                     83.905200
# 75%                       0.657260                    216.177610
# max                     223.064370                   2227.927820
#
#        price_change_percentage_1y
# count                   41.000000
# mean                   347.667956
# std                   1247.842884
# min                    -17.567530
# 25%                      0.406170
# 50%                     69.691950
# 75%                    168.372510
# max                   7852.089700

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
numerical_columns = ['price_change_percentage_24h', 'price_change_percentage_7d',	'price_change_percentage_14d',\
                     'price_change_percentage_30d',	'price_change_percentage_60d',	'price_change_percentage_200d',\
                     'price_change_percentage_1y']
scaled_data = StandardScaler().fit_transform(market_data_df[numerical_columns])
scaled_data
# Out:
# array([[ 5.08529366e-01,  4.93193071e-01,  7.72200433e-01,
#          2.35459633e-01, -6.74950963e-02, -3.55953481e-01,
#         -2.51636882e-01],
#        [ 1.85445894e-01,  9.34445040e-01,  5.58692121e-01,
#         -5.43409317e-02, -2.73482725e-01, -1.15759474e-01,
#         -1.99352110e-01],
#        [ 2.17739616e-02, -7.06336853e-01, -2.16804207e-02,
#         -6.10301536e-02,  8.00452481e-03, -5.50246924e-01,
#         -2.82060506e-01],
#        [-4.07643829e-02, -8.10928066e-01,  2.49457974e-01,
#         -5.03879651e-02, -3.73164019e-01, -4.58258816e-01,
#         -2.95546142e-01],
#        [ 1.19303608e+00,  2.00095907e+00,  1.76061001e+00,
#          5.45842065e-01, -2.91202870e-01, -4.99847761e-01,
#         -2.70316950e-01],
#        [ 8.91870708e-01,  1.32729453e+00,  8.00214184e-01,
#         -5.71478992e-02,  7.78653106e-01, -1.88231917e-01,
#         -2.25532605e-01],
#        [ 1.13972400e-02,  2.57225091e+00,  1.10164693e+00,
#         -4.90495415e-01, -9.31954023e-01,  3.87758986e-01,
#         -1.82843995e-02],
#        [ 1.02529802e-01,  1.50800146e+00,  6.48885061e-01,
#          3.28959245e-01, -4.86348899e-01,  6.50796233e-02,
#         -1.55428416e-01],
#        [ 7.74971820e-02,  3.34296562e-01,  8.58519864e-01,
#         -1.26464730e-02, -3.66476990e-01, -4.86265591e-01,
#         -2.92351214e-01],
#        [ 4.48951505e-01, -1.90684278e-01, -2.48043224e-01,
#          5.16340055e-02, -5.29666139e-01, -5.32960809e-01,
#         -2.06028947e-01],
#        [ 3.31279783e-01, -1.61484369e+00, -1.05452114e+00,
#         -7.29931204e-01, -3.50155382e-01, -2.28656819e-02,
#         -3.45702165e-02],
#        [ 3.43522614e-02, -7.33025788e-01, -2.31403893e-02,
#         -6.57751738e-02,  2.92464871e-03, -5.50599321e-01,
#         -2.82232177e-01],
#        [ 1.55709561e-01, -9.22490861e-01,  1.15023636e-01,
#         -2.37488260e-01, -6.42836699e-01, -5.08220490e-01,
#         -2.96329571e-01],
#        [ 2.62722790e-01,  1.79260243e+00,  2.20266503e+00,
#          1.43784246e+00,  8.93864936e-01, -1.55892797e-01,
#         -1.67644252e-01],
#        [ 1.30049529e-01, -4.10175729e-02,  1.47155030e-01,
#         -5.43776301e-01,  1.20115762e-01, -2.41118188e-01,
#         -2.34014125e-01],
#        [-1.51583411e-01,  7.08195735e-01,  2.58012326e-01,
#         -6.02296039e-01, -9.56048701e-01, -4.49210952e-01,
#         -1.68478608e-01],
#        [-9.23202741e-01, -1.43735894e+00, -6.29962775e-01,
#         -4.60558015e-01, -5.85038908e-02, -4.57282624e-01,
#         -1.66900457e-01],
#        [-2.77542986e-01, -3.85208910e-01, -1.53243165e-01,
#         -3.71816490e-01, -6.56403341e-01, -3.53387283e-01,
#         -2.70874088e-01],
#        [-2.55978040e-01,  1.84027440e+00,  6.43564878e-01,
#          1.16538212e-01, -1.51912822e-01, -1.17565353e-01,
#         -2.15190977e-01],
#        [ 1.80851132e-01, -7.04931420e-01, -1.81614685e-03,
#         -1.43236947e-01,  1.60603798e-02, -5.51146420e-01,
#         -2.82309887e-01],
#        [ 2.86545668e-01, -3.26301416e-01, -1.21267030e+00,
#         -9.03133859e-01,  2.90969825e-01, -1.81187334e-01,
#         -1.75550428e-01],
#        [ 5.15453442e-01,  4.61843180e-01,  7.69975432e-01,
#          2.24045375e-01, -7.46741671e-02, -3.55053705e-01,
#         -2.51623389e-01],
#        [ 5.17582538e-02, -9.28380975e-01, -8.71917511e-01,
#          5.87817038e-02, -1.59249637e-01, -5.12070892e-01,
#         -2.65036119e-01],
#        [-5.20315039e-02, -4.57229014e-01,  3.25221197e-02,
#         -1.84488686e-01, -7.08090069e-02, -4.51982345e-01,
#         -2.62140444e-01],
#        [-2.17983910e-01, -8.49381348e-01,  2.97632101e-01,
#         -1.99820170e-01,  1.77312724e+00, -4.73610984e-02,
#         -1.19226165e-01],
#        [ 6.13385000e-02, -7.06668758e-01, -1.53208558e-02,
#         -5.86935760e-02,  4.01731582e-03, -5.50002649e-01,
#         -2.81963356e-01],
#        [ 2.59097324e-01,  2.49508456e-01, -4.78952718e-01,
#         -2.18996632e-01, -7.35815146e-01, -3.29179315e-01,
#         -2.85309811e-01],
#        [ 5.85088683e-01, -9.94231467e-01, -2.21710811e+00,
#         -6.03897825e-01, -9.30422964e-01,  7.71490396e-02,
#         -1.17481544e-01],
#        [-1.27467490e-01,  9.29118687e-01,  6.77532109e-01,
#          2.23834007e-01, -4.37067731e-01, -2.65163438e-01,
#         -2.14828585e-01],
#        [-1.61218775e+00, -1.68202656e+00, -8.16920931e-01,
#          1.14860683e+00,  1.71264110e+00,  1.50299207e+00,
#          2.86976907e-01],
#        [-2.96940167e-01,  9.47631360e-02,  4.00395074e-02,
#         -3.58829654e-01, -5.58527342e-01, -5.35731946e-01,
#         -2.84071416e-01],
#        [-7.13122190e-02, -2.29483757e-01, -1.75543942e-01,
#          5.18822668e-02, -5.51759945e-01, -5.26060334e-01,
#         -2.73061627e-01],
#        [-4.98104189e+00, -4.51782898e-02, -1.20695612e+00,
#         -1.21212587e+00,  4.77355426e-02,  4.63238025e+00,
#          6.08862545e+00],
#        [-1.25168231e-01,  5.80730108e-01, -2.02356361e-01,
#          5.82911022e-01, -3.95923001e-01, -3.58240047e-01,
#         -2.73433342e-01],
#        [-1.42857388e+00, -2.55101681e-02, -1.62885923e+00,
#         -8.60353737e-01, -8.40713540e-01,  8.98815486e-01,
#          2.68647377e-01],
#        [ 1.91981234e+00,  3.70447157e-01, -1.61976101e+00,
#         -4.09716316e-01,  1.69648044e+00,  8.11206969e-01,
#         -2.18878129e-02],
#        [ 1.04553034e+00, -6.18328162e-01,  2.90705393e+00,
#          5.35145461e+00,  4.76991278e+00,  3.14887546e+00,
#          1.34848839e+00],
#        [-4.09044076e-01, -9.06962812e-01, -1.29898610e+00,
#         -1.39315260e+00, -6.96936973e-01, -4.22834707e-01,
#         -2.92343790e-01],
#        [ 4.14710578e-01,  4.14044166e-01, -4.73857773e-02,
#         -4.65379896e-01,  1.28184655e-01, -4.16502012e-01,
#         -1.45469278e-01],
#        [ 7.80381841e-02, -6.87745436e-01, -9.19092169e-03,
#         -5.82143470e-02,  7.38829646e-03, -5.50440743e-01,
#         -2.81746818e-01],
#        [ 1.21745256e+00, -6.07713570e-01, -9.07065528e-01,
#          4.49939006e-01, -6.62529501e-01,  5.72366557e-01,
#         -1.32481673e-01]])

# %%
# Create a DataFrame with the scaled data
scaled_df = pd.DataFrame(scaled_data)

# Copy the crypto names from the original data
scaled_df['coin_id'] = market_data_df.index

# Set the coinid column as index
scaled_df.set_index(['coin_id'], inplace=True)

# Display sample data
scaled_df.head()
# Out:
#                      0         1         2         3         4         5  \
# coin_id
# bitcoin       0.508529  0.493193  0.772200  0.235460 -0.067495 -0.355953
# ethereum      0.185446  0.934445  0.558692 -0.054341 -0.273483 -0.115759
# tether        0.021774 -0.706337 -0.021680 -0.061030  0.008005 -0.550247
# ripple       -0.040764 -0.810928  0.249458 -0.050388 -0.373164 -0.458259
# bitcoin-cash  1.193036  2.000959  1.760610  0.545842 -0.291203 -0.499848
#
#                      6
# coin_id
# bitcoin      -0.251637
# ethereum     -0.199352
# tether       -0.282061
# ripple       -0.295546
# bitcoin-cash -0.270317

# %%
# To rename the columns 0, 1, 2, 3, 4, 5, and 6 without copying their values
scaled_df.columns = ['price_change_percentage_24h', 'price_change_percentage_7d',	'price_change_percentage_14d',\
                     'price_change_percentage_30d',	'price_change_percentage_60d',	'price_change_percentage_200d',\
                     'price_change_percentage_1y']
scaled_df.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# bitcoin                         -0.067495                     -0.355953
# ethereum                        -0.273483                     -0.115759
# tether                           0.008005                     -0.550247
# ripple                          -0.373164                     -0.458259
# bitcoin-cash                    -0.291203                     -0.499848
#
#               price_change_percentage_1y
# coin_id
# bitcoin                        -0.251637
# ethereum                       -0.199352
# tether                         -0.282061
# ripple                         -0.295546
# bitcoin-cash                   -0.270317

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# Create a list with the number of k-values to try
# Use a range from 1 to 11
k_values = list(range(1, 11))

# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using the scaled DataFrame
# 3. Append the model.inertia_ to the inertia list
for k in k_values:
    k_model = KMeans(n_clusters=k, random_state=42)
    # To fit the model to your data
    k_model.fit(scaled_df)
    # To append the inertia value to the list
    inertia.append(k_model.inertia_)

# Create a dictionary with the data to plot the Elbow curve
elbow_data = {'k_values': k_values, 'inertia': inertia}

# Create a DataFrame with the data to plot the Elbow curve
elbow_df = pd.DataFrame(elbow_data)

# Display the DataFrame
elbow_df
# Out:
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#    k_values     inertia
# 0         1  287.000000
# 1         2  212.123342
# 2         3  170.193571
# 3         4   79.022435
# 4         5   71.097914
# 5         6   66.108827
# 6         7   54.488123
# 7         8   43.224693
# 8         9   32.860884
# 9        10   28.404885

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
figure = elbow_df.plot(kind='scatter', x="k_values", y="inertia", title='Inertia vs. Number of Clusters',\
                       figsize=(10, 6), marker='o', grid=True, \
                        xlabel='Number of Clusters (k)', ylabel='Inertia')

# %% [markdown]
# #### Answer the following question:
# **Question:** What is the best value for `k`?
#
# **Answer:**
# From the elbow curve's observation, one can deduce that the best value for k is 4, where the elbw started.

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled Data.

# %%
# Initialize the K-Means model using the best value for k
kmeans_model = KMeans(n_clusters=4, n_init='auto', random_state=0)

# %%
# Fit the K-Means model using the scaled data
kmeans_model.fit(scaled_df)
# Out:
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=0)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data
predicted_clusters = kmeans_model.predict(scaled_df)

# View the resulting array of cluster values.
predicted_clusters
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2,
#        0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 1, 2, 0, 0, 3, 0, 0, 0, 0])

# %%
# Create a copy of the DataFrame
df_with_clusters = scaled_df.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
df_with_clusters['Predicted Clusters'] = predicted_clusters

# Display sample data
df_with_clusters
# Out:
#                       price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                                  0.508529                    0.493193
# ethereum                                 0.185446                    0.934445
# tether                                   0.021774                   -0.706337
# ripple                                  -0.040764                   -0.810928
# bitcoin-cash                             1.193036                    2.000959
# binancecoin                              0.891871                    1.327295
# chainlink                                0.011397                    2.572251
# cardano                                  0.102530                    1.508001
# litecoin                                 0.077497                    0.334297
# bitcoin-cash-sv                          0.448952                   -0.190684
# crypto-com-chain                         0.331280                   -1.614844
# usd-coin                                 0.034352                   -0.733026
# eos                                      0.155710                   -0.922491
# monero                                   0.262723                    1.792602
# tron                                     0.130050                   -0.041018
# tezos                                   -0.151583                    0.708196
# okb                                     -0.923203                   -1.437359
# stellar                                 -0.277543                   -0.385209
# cosmos                                  -0.255978                    1.840274
# cdai                                     0.180851                   -0.704931
# neo                                      0.286546                   -0.326301
# wrapped-bitcoin                          0.515453                    0.461843
# leo-token                                0.051758                   -0.928381
# huobi-token                             -0.052032                   -0.457229
# nem                                     -0.217984                   -0.849381
# binance-usd                              0.061339                   -0.706669
# iota                                     0.259097                    0.249508
# vechain                                  0.585089                   -0.994231
# zcash                                   -0.127467                    0.929119
# theta-token                             -1.612188                   -1.682027
# dash                                    -0.296940                    0.094763
# ethereum-classic                        -0.071312                   -0.229484
# ethlend                                 -4.981042                   -0.045178
# maker                                   -0.125168                    0.580730
# havven                                  -1.428574                   -0.025510
# omisego                                  1.919812                    0.370447
# celsius-degree-token                     1.045530                   -0.618328
# ontology                                -0.409044                   -0.906963
# ftx-token                                0.414711                    0.414044
# true-usd                                 0.078038                   -0.687745
# digibyte                                 1.217453                   -0.607714
#
#                       price_change_percentage_14d  \
# coin_id
# bitcoin                                  0.772200
# ethereum                                 0.558692
# tether                                  -0.021680
# ripple                                   0.249458
# bitcoin-cash                             1.760610
# binancecoin                              0.800214
# chainlink                                1.101647
# cardano                                  0.648885
# litecoin                                 0.858520
# bitcoin-cash-sv                         -0.248043
# crypto-com-chain                        -1.054521
# usd-coin                                -0.023140
# eos                                      0.115024
# monero                                   2.202665
# tron                                     0.147155
# tezos                                    0.258012
# okb                                     -0.629963
# stellar                                 -0.153243
# cosmos                                   0.643565
# cdai                                    -0.001816
# neo                                     -1.212670
# wrapped-bitcoin                          0.769975
# leo-token                               -0.871918
# huobi-token                              0.032522
# nem                                      0.297632
# binance-usd                             -0.015321
# iota                                    -0.478953
# vechain                                 -2.217108
# zcash                                    0.677532
# theta-token                             -0.816921
# dash                                     0.040040
# ethereum-classic                        -0.175544
# ethlend                                 -1.206956
# maker                                   -0.202356
# havven                                  -1.628859
# omisego                                 -1.619761
# celsius-degree-token                     2.907054
# ontology                                -1.298986
# ftx-token                               -0.047386
# true-usd                                -0.009191
# digibyte                                -0.907066
#
#                       price_change_percentage_30d  \
# coin_id
# bitcoin                                  0.235460
# ethereum                                -0.054341
# tether                                  -0.061030
# ripple                                  -0.050388
# bitcoin-cash                             0.545842
# binancecoin                             -0.057148
# chainlink                               -0.490495
# cardano                                  0.328959
# litecoin                                -0.012646
# bitcoin-cash-sv                          0.051634
# crypto-com-chain                        -0.729931
# usd-coin                                -0.065775
# eos                                     -0.237488
# monero                                   1.437842
# tron                                    -0.543776
# tezos                                   -0.602296
# okb                                     -0.460558
# stellar                                 -0.371816
# cosmos                                   0.116538
# cdai                                    -0.143237
# neo                                     -0.903134
# wrapped-bitcoin                          0.224045
# leo-token                                0.058782
# huobi-token                             -0.184489
# nem                                     -0.199820
# binance-usd                             -0.058694
# iota                                    -0.218997
# vechain                                 -0.603898
# zcash                                    0.223834
# theta-token                              1.148607
# dash                                    -0.358830
# ethereum-classic                         0.051882
# ethlend                                 -1.212126
# maker                                    0.582911
# havven                                  -0.860354
# omisego                                 -0.409716
# celsius-degree-token                     5.351455
# ontology                                -1.393153
# ftx-token                               -0.465380
# true-usd                                -0.058214
# digibyte                                 0.449939
#
#                       price_change_percentage_60d  \
# coin_id
# bitcoin                                 -0.067495
# ethereum                                -0.273483
# tether                                   0.008005
# ripple                                  -0.373164
# bitcoin-cash                            -0.291203
# binancecoin                              0.778653
# chainlink                               -0.931954
# cardano                                 -0.486349
# litecoin                                -0.366477
# bitcoin-cash-sv                         -0.529666
# crypto-com-chain                        -0.350155
# usd-coin                                 0.002925
# eos                                     -0.642837
# monero                                   0.893865
# tron                                     0.120116
# tezos                                   -0.956049
# okb                                     -0.058504
# stellar                                 -0.656403
# cosmos                                  -0.151913
# cdai                                     0.016060
# neo                                      0.290970
# wrapped-bitcoin                         -0.074674
# leo-token                               -0.159250
# huobi-token                             -0.070809
# nem                                      1.773127
# binance-usd                              0.004017
# iota                                    -0.735815
# vechain                                 -0.930423
# zcash                                   -0.437068
# theta-token                              1.712641
# dash                                    -0.558527
# ethereum-classic                        -0.551760
# ethlend                                  0.047736
# maker                                   -0.395923
# havven                                  -0.840714
# omisego                                  1.696480
# celsius-degree-token                     4.769913
# ontology                                -0.696937
# ftx-token                                0.128185
# true-usd                                 0.007388
# digibyte                                -0.662530
#
#                       price_change_percentage_200d  \
# coin_id
# bitcoin                                  -0.355953
# ethereum                                 -0.115759
# tether                                   -0.550247
# ripple                                   -0.458259
# bitcoin-cash                             -0.499848
# binancecoin                              -0.188232
# chainlink                                 0.387759
# cardano                                   0.065080
# litecoin                                 -0.486266
# bitcoin-cash-sv                          -0.532961
# crypto-com-chain                         -0.022866
# usd-coin                                 -0.550599
# eos                                      -0.508220
# monero                                   -0.155893
# tron                                     -0.241118
# tezos                                    -0.449211
# okb                                      -0.457283
# stellar                                  -0.353387
# cosmos                                   -0.117565
# cdai                                     -0.551146
# neo                                      -0.181187
# wrapped-bitcoin                          -0.355054
# leo-token                                -0.512071
# huobi-token                              -0.451982
# nem                                      -0.047361
# binance-usd                              -0.550003
# iota                                     -0.329179
# vechain                                   0.077149
# zcash                                    -0.265163
# theta-token                               1.502992
# dash                                     -0.535732
# ethereum-classic                         -0.526060
# ethlend                                   4.632380
# maker                                    -0.358240
# havven                                    0.898815
# omisego                                   0.811207
# celsius-degree-token                      3.148875
# ontology                                 -0.422835
# ftx-token                                -0.416502
# true-usd                                 -0.550441
# digibyte                                  0.572367
#
#                       price_change_percentage_1y  Predicted Clusters
# coin_id
# bitcoin                                -0.251637                   2
# ethereum                               -0.199352                   2
# tether                                 -0.282061                   0
# ripple                                 -0.295546                   0
# bitcoin-cash                           -0.270317                   2
# binancecoin                            -0.225533                   2
# chainlink                              -0.018284                   2
# cardano                                -0.155428                   2
# litecoin                               -0.292351                   2
# bitcoin-cash-sv                        -0.206029                   0
# crypto-com-chain                       -0.034570                   0
# usd-coin                               -0.282232                   0
# eos                                    -0.296330                   0
# monero                                 -0.167644                   2
# tron                                   -0.234014                   0
# tezos                                  -0.168479                   2
# okb                                    -0.166900                   0
# stellar                                -0.270874                   0
# cosmos                                 -0.215191                   2
# cdai                                   -0.282310                   0
# neo                                    -0.175550                   0
# wrapped-bitcoin                        -0.251623                   2
# leo-token                              -0.265036                   0
# huobi-token                            -0.262140                   0
# nem                                    -0.119226                   0
# binance-usd                            -0.281963                   0
# iota                                   -0.285310                   0
# vechain                                -0.117482                   0
# zcash                                  -0.214829                   2
# theta-token                             0.286977                   0
# dash                                   -0.284071                   0
# ethereum-classic                       -0.273062                   0
# ethlend                                 6.088625                   1
# maker                                  -0.273433                   2
# havven                                  0.268647                   0
# omisego                                -0.021888                   0
# celsius-degree-token                    1.348488                   3
# ontology                               -0.292344                   0
# ftx-token                              -0.145469                   0
# true-usd                               -0.281747                   0
# digibyte                               -0.132482                   0

# %%
# Create a scatter plot using Pandas plot by setting
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Use "rainbow" for the color to better visualize the data.
figure = df_with_clusters.plot(kind = 'scatter', x="price_change_percentage_24h", y="price_change_percentage_7d", \
                               title='Scatter Plot for the DataFrame with Clusters', figsize=(10, 6), marker='o', grid=True, \
                                xlabel='Price Change Percentage 24h', ylabel='Price Change Percentage 7d', colormap='rainbow')
# Out:
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1345: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` on the original scaled DataFrame to reduce to three principal components.
df_pca = pd.DataFrame(data=pca.fit_transform(scaled_df), columns=['PC1', 'PC2', 'PC3'], index=scaled_df.index)

# View the first five rows of the DataFrame.
df_pca.head()
# Out:
#                    PC1       PC2       PC3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %%
# Retrieve the explained variance to determine how much information  can be attributed to each principal component.
for i, ratio in enumerate(pca.explained_variance_ratio_):
    print(f"Explained Variance for PC{i+1}: {ratio:.4f}")
# Out:
# Explained Variance for PC1: 0.3720
# Explained Variance for PC2: 0.3470
# Explained Variance for PC3: 0.1760

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:**
# PC1: 0.3720
# PC2: 0.3470
# PC3: 0.1760

# %%
# Create a new DataFrame with the PCA data.
# Note: The code for this step is provided for you

# Creating a DataFrame with the PCA data


# Copy the crypto names from the original data


# Set the coinid column as index


# Display sample data

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values to try
# Use a range from 1 to 11
k_values = range(1, 11)

# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using PCA DataFrame.
# 3. Append the model.inertia_ to the inertia list
for k in k_values:
    k_model = KMeans(n_clusters=k, random_state=42)
    k_model.fit(pca.fit_transform(df_pca))
    inertia.append(k_model.inertia_)

# Create a dictionary with the data to plot the Elbow curve
elbow_data = {'k': k_values, 'inertia': inertia}

# Create a DataFrame with the data to plot the Elbow curve
df_elbow = pd.DataFrame(elbow_data)

# Display the DataFrame
df_elbow
# Out:
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#     k     inertia
# 0   1  256.874086
# 1   2  182.339530
# 2   3  140.431833
# 3   4   49.665497
# 4   5   42.051901
# 5   6   31.749005
# 6   7   28.031869
# 7   8   19.451747
# 8   9   13.814082
# 9  10   10.630648

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
pca_figure = df_elbow.plot(kind='scatter', x="k", y="inertia", title='Inertia vs. Number of Clusters',\
                       figsize=(10, 6), marker='o', grid=True, \
                        xlabel='Number of Clusters (k)', ylabel='Inertia')
pca_figure
# Out:
# <Axes: title={'center': 'Inertia vs. Number of Clusters'}, xlabel='Number of Clusters (k)', ylabel='Inertia'>

# %% [markdown]
# #### Answer the following questions:
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:**
#   4
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:**
#   No, it does not.

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialize the K-Means model using the best value for k
pca_kmeans_model = KMeans(n_clusters=4, n_init='auto', random_state=0)

# %%
# Fit the K-Means model using the PCA data
pca_kmeans_model.fit(df_pca)
# Out:
# c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=0)

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data
pca_predicted_clusters = pca_kmeans_model.predict(df_pca)

# Print the resulting array of cluster values.
pca_predicted_clusters
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2,
#        0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 1, 2, 0, 0, 3, 0, 0, 0, 0])

# %%
# Create a copy of the DataFrame with the PCA data
pca_df_with_clusters = df_pca.copy()

# Add a new column to the DataFrame with the predicted clusters
#pca_df_with_clusters['PCA Predicted Clusters'] = pca_predicted_clusters

# Display sample data
pca_df_with_clusters
# Out:
#                            PC1       PC2       PC3
# coin_id
# bitcoin              -0.600667  0.842760  0.461595
# ethereum             -0.458261  0.458466  0.952877
# tether               -0.433070 -0.168126 -0.641752
# ripple               -0.471835 -0.222660 -0.479053
# bitcoin-cash         -1.157800  2.041209  1.859715
# binancecoin          -0.516534  1.388377  0.804071
# chainlink            -0.450711  0.517699  2.846143
# cardano              -0.345600  0.729439  1.478013
# litecoin             -0.649468  0.432165  0.600303
# bitcoin-cash-sv      -0.759014 -0.201200 -0.217653
# crypto-com-chain     -0.248198 -1.376252 -1.462026
# usd-coin             -0.438408 -0.175337 -0.663388
# eos                  -0.693425 -0.473815 -0.527597
# monero                0.060499  2.909404  1.498571
# tron                 -0.393352 -0.108192 -0.012756
# tezos                -0.796176 -0.494409  1.082812
# okb                   0.064075 -1.269825 -1.098829
# stellar              -0.489015 -0.732719 -0.062543
# cosmos               -0.306272  0.703415  1.714224
# cdai                 -0.513528 -0.142802 -0.656566
# neo                  -0.362120 -0.986914 -0.728752
# wrapped-bitcoin      -0.604265  0.827398  0.439316
# leo-token            -0.413296 -0.674115 -1.076628
# huobi-token          -0.407483 -0.212507 -0.351426
# nem                   0.608974  0.563532 -1.148742
# binance-usd          -0.450211 -0.151019 -0.647401
# iota                 -0.764665 -0.517886  0.204990
# vechain              -0.556315 -1.938209 -1.261776
# zcash                -0.425147  0.492976  1.058048
# theta-token           2.676868 -0.013954 -1.965207
# dash                 -0.613923 -0.479337  0.339565
# ethereum-classic     -0.579924 -0.356334 -0.114942
# ethlend               8.089018 -3.896891  2.301382
# maker                -0.389045  0.165041  0.379414
# havven                0.865762 -2.261882  0.275583
# omisego               0.111675  0.428316 -1.205398
# celsius-degree-token  4.792395  6.767679 -1.986985
# ontology             -0.632355 -2.108117 -0.652227
# ftx-token            -0.593142  0.021485  0.209911
# true-usd             -0.458131 -0.135734 -0.635284
# digibyte             -0.297910 -0.191126 -0.909602

# %%
# Create a scatter plot using hvPlot by setting `x="PCA1"` and `y="PCA2"`.
pca_figure = pca_df_with_clusters.hvplot(kind='scatter', x="PC1", y="PC2", title='Scatter hvPlot for the PC DataFrame with Clusters',\
                      marker='o', grid=True, \
                        xlabel='PC1', ylabel='PPC2', colormap='rainbow')
pca_figure
#scatter_plot = pca_df_with_clusters.hvplot.scatter(x="PC1", y="PC2")
#pca_figure
# Out:
# :Scatter   [PC1]   (PC2)

# %% [markdown]
# ### Determine the Weights of Each Feature on each Principal Component

# %%
# Use the columns from the original scaled DataFrame as the index.
weights_df = pd.DataFrame(pca.components_.T, index=scaled_df.columns, columns=['PC1', 'PC2', 'PC3'])
weights_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 2
#       1 # Use the columns from the original scaled DataFrame as the index.
# ----> 2 weights_df = pd.DataFrame(pca.components_.T, index=scaled_df.columns, columns=['PC1', 'PC2', 'PC3'])
#       3 weights_df
#
# File c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\pandas\core\frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)
#     824             copy=_copy,
#     825         )
#     826     else:
# --> 827         mgr = ndarray_to_mgr(
#     828             data,
#     829             index,
#     830             columns,
#     831             dtype=dtype,
#     832             copy=copy,
#     833             typ=manager,
#     834         )
#     836 # For data is list-like, or Iterable (will consume into list)
#     837 elif is_list_like(data):
#
# File c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\pandas\core\internals\construction.py:336, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     331 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     332 index, columns = _get_axes(
#     333     values.shape[0], values.shape[1], index=index, columns=columns
#     334 )
# --> 336 _check_values_indices_shape_match(values, index, columns)
#     338 if typ == "array":
#     339     if issubclass(values.dtype.type, str):
#
# File c:\Users\phessou\AppData\Local\anaconda3\lib\site-packages\pandas\core\internals\construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (3, 3), indices imply (7, 3)

# %%
scaled_df
# Out:
#                       price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                                  0.508529                    0.493193
# ethereum                                 0.185446                    0.934445
# tether                                   0.021774                   -0.706337
# ripple                                  -0.040764                   -0.810928
# bitcoin-cash                             1.193036                    2.000959
# binancecoin                              0.891871                    1.327295
# chainlink                                0.011397                    2.572251
# cardano                                  0.102530                    1.508001
# litecoin                                 0.077497                    0.334297
# bitcoin-cash-sv                          0.448952                   -0.190684
# crypto-com-chain                         0.331280                   -1.614844
# usd-coin                                 0.034352                   -0.733026
# eos                                      0.155710                   -0.922491
# monero                                   0.262723                    1.792602
# tron                                     0.130050                   -0.041018
# tezos                                   -0.151583                    0.708196
# okb                                     -0.923203                   -1.437359
# stellar                                 -0.277543                   -0.385209
# cosmos                                  -0.255978                    1.840274
# cdai                                     0.180851                   -0.704931
# neo                                      0.286546                   -0.326301
# wrapped-bitcoin                          0.515453                    0.461843
# leo-token                                0.051758                   -0.928381
# huobi-token                             -0.052032                   -0.457229
# nem                                     -0.217984                   -0.849381
# binance-usd                              0.061339                   -0.706669
# iota                                     0.259097                    0.249508
# vechain                                  0.585089                   -0.994231
# zcash                                   -0.127467                    0.929119
# theta-token                             -1.612188                   -1.682027
# dash                                    -0.296940                    0.094763
# ethereum-classic                        -0.071312                   -0.229484
# ethlend                                 -4.981042                   -0.045178
# maker                                   -0.125168                    0.580730
# havven                                  -1.428574                   -0.025510
# omisego                                  1.919812                    0.370447
# celsius-degree-token                     1.045530                   -0.618328
# ontology                                -0.409044                   -0.906963
# ftx-token                                0.414711                    0.414044
# true-usd                                 0.078038                   -0.687745
# digibyte                                 1.217453                   -0.607714
#
#                       price_change_percentage_14d  \
# coin_id
# bitcoin                                  0.772200
# ethereum                                 0.558692
# tether                                  -0.021680
# ripple                                   0.249458
# bitcoin-cash                             1.760610
# binancecoin                              0.800214
# chainlink                                1.101647
# cardano                                  0.648885
# litecoin                                 0.858520
# bitcoin-cash-sv                         -0.248043
# crypto-com-chain                        -1.054521
# usd-coin                                -0.023140
# eos                                      0.115024
# monero                                   2.202665
# tron                                     0.147155
# tezos                                    0.258012
# okb                                     -0.629963
# stellar                                 -0.153243
# cosmos                                   0.643565
# cdai                                    -0.001816
# neo                                     -1.212670
# wrapped-bitcoin                          0.769975
# leo-token                               -0.871918
# huobi-token                              0.032522
# nem                                      0.297632
# binance-usd                             -0.015321
# iota                                    -0.478953
# vechain                                 -2.217108
# zcash                                    0.677532
# theta-token                             -0.816921
# dash                                     0.040040
# ethereum-classic                        -0.175544
# ethlend                                 -1.206956
# maker                                   -0.202356
# havven                                  -1.628859
# omisego                                 -1.619761
# celsius-degree-token                     2.907054
# ontology                                -1.298986
# ftx-token                               -0.047386
# true-usd                                -0.009191
# digibyte                                -0.907066
#
#                       price_change_percentage_30d  \
# coin_id
# bitcoin                                  0.235460
# ethereum                                -0.054341
# tether                                  -0.061030
# ripple                                  -0.050388
# bitcoin-cash                             0.545842
# binancecoin                             -0.057148
# chainlink                               -0.490495
# cardano                                  0.328959
# litecoin                                -0.012646
# bitcoin-cash-sv                          0.051634
# crypto-com-chain                        -0.729931
# usd-coin                                -0.065775
# eos                                     -0.237488
# monero                                   1.437842
# tron                                    -0.543776
# tezos                                   -0.602296
# okb                                     -0.460558
# stellar                                 -0.371816
# cosmos                                   0.116538
# cdai                                    -0.143237
# neo                                     -0.903134
# wrapped-bitcoin                          0.224045
# leo-token                                0.058782
# huobi-token                             -0.184489
# nem                                     -0.199820
# binance-usd                             -0.058694
# iota                                    -0.218997
# vechain                                 -0.603898
# zcash                                    0.223834
# theta-token                              1.148607
# dash                                    -0.358830
# ethereum-classic                         0.051882
# ethlend                                 -1.212126
# maker                                    0.582911
# havven                                  -0.860354
# omisego                                 -0.409716
# celsius-degree-token                     5.351455
# ontology                                -1.393153
# ftx-token                               -0.465380
# true-usd                                -0.058214
# digibyte                                 0.449939
#
#                       price_change_percentage_60d  \
# coin_id
# bitcoin                                 -0.067495
# ethereum                                -0.273483
# tether                                   0.008005
# ripple                                  -0.373164
# bitcoin-cash                            -0.291203
# binancecoin                              0.778653
# chainlink                               -0.931954
# cardano                                 -0.486349
# litecoin                                -0.366477
# bitcoin-cash-sv                         -0.529666
# crypto-com-chain                        -0.350155
# usd-coin                                 0.002925
# eos                                     -0.642837
# monero                                   0.893865
# tron                                     0.120116
# tezos                                   -0.956049
# okb                                     -0.058504
# stellar                                 -0.656403
# cosmos                                  -0.151913
# cdai                                     0.016060
# neo                                      0.290970
# wrapped-bitcoin                         -0.074674
# leo-token                               -0.159250
# huobi-token                             -0.070809
# nem                                      1.773127
# binance-usd                              0.004017
# iota                                    -0.735815
# vechain                                 -0.930423
# zcash                                   -0.437068
# theta-token                              1.712641
# dash                                    -0.558527
# ethereum-classic                        -0.551760
# ethlend                                  0.047736
# maker                                   -0.395923
# havven                                  -0.840714
# omisego                                  1.696480
# celsius-degree-token                     4.769913
# ontology                                -0.696937
# ftx-token                                0.128185
# true-usd                                 0.007388
# digibyte                                -0.662530
#
#                       price_change_percentage_200d  price_change_percentage_1y
# coin_id
# bitcoin                                  -0.355953                   -0.251637
# ethereum                                 -0.115759                   -0.199352
# tether                                   -0.550247                   -0.282061
# ripple                                   -0.458259                   -0.295546
# bitcoin-cash                             -0.499848                   -0.270317
# binancecoin                              -0.188232                   -0.225533
# chainlink                                 0.387759                   -0.018284
# cardano                                   0.065080                   -0.155428
# litecoin                                 -0.486266                   -0.292351
# bitcoin-cash-sv                          -0.532961                   -0.206029
# crypto-com-chain                         -0.022866                   -0.034570
# usd-coin                                 -0.550599                   -0.282232
# eos                                      -0.508220                   -0.296330
# monero                                   -0.155893                   -0.167644
# tron                                     -0.241118                   -0.234014
# tezos                                    -0.449211                   -0.168479
# okb                                      -0.457283                   -0.166900
# stellar                                  -0.353387                   -0.270874
# cosmos                                   -0.117565                   -0.215191
# cdai                                     -0.551146                   -0.282310
# neo                                      -0.181187                   -0.175550
# wrapped-bitcoin                          -0.355054                   -0.251623
# leo-token                                -0.512071                   -0.265036
# huobi-token                              -0.451982                   -0.262140
# nem                                      -0.047361                   -0.119226
# binance-usd                              -0.550003                   -0.281963
# iota                                     -0.329179                   -0.285310
# vechain                                   0.077149                   -0.117482
# zcash                                    -0.265163                   -0.214829
# theta-token                               1.502992                    0.286977
# dash                                     -0.535732                   -0.284071
# ethereum-classic                         -0.526060                   -0.273062
# ethlend                                   4.632380                    6.088625
# maker                                    -0.358240                   -0.273433
# havven                                    0.898815                    0.268647
# omisego                                   0.811207                   -0.021888
# celsius-degree-token                      3.148875                    1.348488
# ontology                                 -0.422835                   -0.292344
# ftx-token                                -0.416502                   -0.145469
# true-usd                                 -0.550441                   -0.281747
# digibyte                                  0.572367                   -0.132482

# %% [markdown]
# #### Answer the following question:
#
# * **Question:** Which features have the strongest positive or negative influence on each component?
#
# * **Answer:**
# Not applicable as all of the values are NaN.
